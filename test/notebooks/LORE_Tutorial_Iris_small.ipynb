# %% [markdown]
# ### Reducción del dataset Iris - trabajamos con Merge trees

# %%
from lore_sa.dataset import TabularDataset
import pandas as pd
from sklearn.model_selection import train_test_split

from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.experimental import enable_halving_search_cv
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from lore_sa.bbox import sklearn_classifier_bbox

from sklearn.metrics import classification_report, accuracy_score

from lore_sa.lore import TabularRandomGeneratorLore
from lore_sa.lore import TabularGeneticGeneratorLore

from lore_sa.encoder_decoder import ColumnTransformerEnc

from lore_sa.neighgen import RandomGenerator
from lore_sa.neighgen import GeneticGenerator

from lore_sa.surrogate import DecisionTreeSurrogate
# Out:
# 2025-05-20 13:37:12,424 numexpr.utils INFO     Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2025-05-20 13:37:12,424 numexpr.utils INFO     NumExpr defaulting to 8 threads.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from lore_sa.dataset import TabularDataset
import numpy as np

# Cargar el dataset original
df = pd.read_csv('test/resources/iris.csv')

# Convertir la columna target a nombres de clases
species_mapping = {0: "setosa", 1: "versicolor", 2: "virginica"}
df["target"] = df["target"].map(species_mapping)

# Reducir el dataset manteniendo balance de clases
df_small = df.groupby("target").apply(lambda x: x.sample(n=6, random_state=42)).reset_index(drop=True)

# Guardar el nuevo dataset reducido
df_small.to_csv('test/resources/iris_small.csv', index=False)

# Cargarlo en TabularDataset

# Iris_categorical --> 150 rows
# Iris_small --> less rows

dataset_small = TabularDataset.from_csv('test/resources/iris_categorical.csv', class_name="target")

feature_names = list(dataset_small.descriptor["numeric"].keys()) + list(dataset_small.descriptor["categorical"].keys())
class_names = dataset_small.df["target"].unique().tolist()

print(dataset_small.descriptor.keys())


dataset_small.df
# Out:
# 2025-05-20 13:37:14,073 root         INFO     test/resources/iris_categorical.csv file imported
# dict_keys(['numeric', 'categorical', 'ordinal', 'target'])
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#         target
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 5 columns]

# %%
dataset_small.df.value_counts("target")
# Out:
# target
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
def train_model(dataset: TabularDataset):
    preprocessor = ColumnTransformer(
        transformers=[
            ('num', StandardScaler(), [0,1,2,3]),
            ('cat', OrdinalEncoder(), [])
        ]
    )
    model = make_pipeline(preprocessor, DecisionTreeClassifier(max_depth=3, random_state=42))
    
    X_train, X_test, y_train, y_test = train_test_split(dataset.df.loc[:, 'sepal length (cm)':'petal width (cm)'].values, dataset.df['target'].values,
                test_size=0.3, random_state=42, stratify=dataset.df['target'].values)
    

    model.fit(X_train, y_train)

    
    return sklearn_classifier_bbox.sklearnBBox(model), X_train, y_train, X_test, y_test

# %% [markdown]
# ### Generación de explicaciones en el dataset reducido

# %%
from sklearn.metrics import classification_report, accuracy_score
from lore_sa.lore import TabularRandomGeneratorLore

# Entrenar el modelo en el dataset reducido
bbox_small, X_train, y_train, X_test, y_test = train_model(dataset_small)

# Obtener predicciones en el conjunto de prueba
y_pred = bbox_small.bbox.predict(X_test)

# Imprimir métricas
print("🔍 Reporte de clasificación:\n")
print(classification_report(y_test, y_pred))
print(f" Precisión del modelo: {accuracy_score(y_test, y_pred):.2f}")
# Out:
# 🔍 Reporte de clasificación:
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        15
#   versicolor       0.94      1.00      0.97        15
#    virginica       1.00      0.93      0.97        15
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
#
#  Precisión del modelo: 0.98

# %% [markdown]
# Generamos los vecinos con el algoritmo genético

# %%
# Crear LORE
tabularLore_small = TabularGeneticGeneratorLore(bbox_small, dataset_small) # El Genetic Generator funciona mucho mejor que el Random Generator

# Elegir una instancia para explicar
num_row = 5  # Puedes cambiar el índice para probar distintas instancias
x = dataset_small.df.iloc[num_row][:-1]

# Generar explicación
explanation_small = tabularLore_small.explain_instance(x, merge=True)

# %%
from graphviz import Digraph
from IPython.display import Image

from lore_sa.surrogate.decision_tree import EnsembleDecisionTreeSurrogate, SuperTree


# Función para visualizar el supertree
def visualize_supertree(tree, feature_names=None, class_names=None):
    dot = Digraph()
    node_id = [0]

    def add_node(node, parent_id=None, edge_label=''):
        curr_id = str(node_id[0])
        node_id[0] += 1

        if node.is_leaf:
            class_index = np.argmax(node.labels)
            class_label = class_names[class_index] if class_names else f"class {class_index}"
            label = f"class: {class_label}\n{node.labels}"
        else:
            fname = f"X_{node.feat}" if feature_names is None else feature_names[node.feat]
            label = f"{fname}"

        dot.node(curr_id, label)

        if parent_id is not None:
            dot.edge(parent_id, curr_id, label=edge_label)

        if not node.is_leaf:
            for i, child in enumerate(node.children):
                if i == 0:
                    label = f"<= {node.intervals[i]:.2f}"
                else:
                    label = f"> {node.intervals[i - 1]:.2f}"
                add_node(child, curr_id, label)

    add_node(tree)
    return dot



def visualize_individual_binary_tree(root_node, feature_names=None, class_names=None):
    dot = Digraph()
    node_id = [0]

    def add_node(node, parent_id=None, edge_label=''):
        curr_id = str(node_id[0])
        node_id[0] += 1

        if node.is_leaf:
            class_index = np.argmax(node.labels)
            class_label = class_names[class_index] if class_names else f"class {class_index}"
            label = f"Clase: {class_label}\n{node.labels}"
        else:
            fname = f"X_{node.feat}" if feature_names is None else feature_names[node.feat]
            label = f"{fname} <= {node.thresh:.2f}"

        dot.node(curr_id, label)

        if parent_id is not None:
            dot.edge(parent_id, curr_id, label=edge_label)

        if not node.is_leaf:
            fname = f"X_{node.feat}" if feature_names is None else feature_names[node.feat]
            add_node(node._left_child, curr_id, f"<= {node.thresh:.2f}")
            add_node(node._right_child, curr_id, f"> {node.thresh:.2f}")

    add_node(root_node)
    return dot
# Out:
# 2025-05-20 13:37:40,829 graphviz._tools DEBUG    deprecate positional args: graphviz.backend.piping.pipe(['renderer', 'formatter', 'neato_no_op', 'quiet'])
# 2025-05-20 13:37:40,832 graphviz._tools DEBUG    deprecate positional args: graphviz.backend.rendering.render(['renderer', 'formatter', 'neato_no_op', 'quiet'])
# 2025-05-20 13:37:40,836 graphviz._tools DEBUG    deprecate positional args: graphviz.backend.unflattening.unflatten(['stagger', 'fanout', 'chain', 'encoding'])
# 2025-05-20 13:37:40,840 graphviz._tools DEBUG    deprecate positional args: graphviz.backend.viewing.view(['quiet'])
# 2025-05-20 13:37:40,849 graphviz._tools DEBUG    deprecate positional args: graphviz.quoting.quote(['is_html_string', 'is_valid_id', 'dot_keywords', 'endswith_odd_number_of_backslashes', 'escape_unescaped_quotes'])
# 2025-05-20 13:37:40,849 graphviz._tools DEBUG    deprecate positional args: graphviz.quoting.a_list(['kwargs', 'attributes'])
# 2025-05-20 13:37:40,851 graphviz._tools DEBUG    deprecate positional args: graphviz.quoting.attr_list(['kwargs', 'attributes'])
# 2025-05-20 13:37:40,852 graphviz._tools DEBUG    deprecate positional args: graphviz.dot.Dot.clear(['keep_attrs'])
# 2025-05-20 13:37:40,853 graphviz._tools DEBUG    deprecate positional args: graphviz.dot.Dot.__iter__(['subgraph'])
# 2025-05-20 13:37:40,853 graphviz._tools DEBUG    deprecate positional args: graphviz.dot.Dot.node(['_attributes'])
# 2025-05-20 13:37:40,854 graphviz._tools DEBUG    deprecate positional args: graphviz.dot.Dot.edge(['_attributes'])
# 2025-05-20 13:37:40,855 graphviz._tools DEBUG    deprecate positional args: graphviz.dot.Dot.attr(['_attributes'])
# 2025-05-20 13:37:40,856 graphviz._tools DEBUG    deprecate positional args: graphviz.dot.Dot.subgraph(['name', 'comment', 'graph_attr', 'node_attr', 'edge_attr', 'body'])
# 2025-05-20 13:37:40,862 graphviz._tools DEBUG    deprecate positional args: graphviz.piping.Pipe._pipe_legacy(['renderer', 'formatter', 'neato_no_op', 'quiet'])
# 2025-05-20 13:37:40,867 graphviz._tools DEBUG    deprecate positional args: graphviz.saving.Save.save(['directory'])
# 2025-05-20 13:37:40,870 graphviz._tools DEBUG    deprecate positional args: graphviz.rendering.Render.render(['directory', 'view', 'cleanup', 'format', 'renderer', 'formatter', 'neato_no_op', 'quiet', 'quiet_view'])
# 2025-05-20 13:37:40,871 graphviz._tools DEBUG    deprecate positional args: graphviz.rendering.Render.view(['directory', 'cleanup', 'quiet', 'quiet_view'])
# 2025-05-20 13:37:40,873 graphviz._tools DEBUG    deprecate positional args: graphviz.unflattening.Unflatten.unflatten(['stagger', 'fanout', 'chain'])
# 2025-05-20 13:37:40,874 graphviz._tools DEBUG    deprecate positional args: graphviz.graphs.BaseGraph.__init__(['comment', 'filename', 'directory', 'format', 'engine', 'encoding', 'graph_attr', 'node_attr', 'edge_attr', 'body', 'strict'])
# 2025-05-20 13:37:40,877 graphviz._tools DEBUG    deprecate positional args: graphviz.sources.Source.from_file(['directory', 'format', 'engine', 'encoding', 'renderer', 'formatter'])
# 2025-05-20 13:37:40,877 graphviz._tools DEBUG    deprecate positional args: graphviz.sources.Source.__init__(['filename', 'directory', 'format', 'engine', 'encoding'])
# 2025-05-20 13:37:40,878 graphviz._tools DEBUG    deprecate positional args: graphviz.sources.Source.save(['directory'])

# %% [markdown]
# #### Árboles inciales antes de la mezcla

# %%
ensemble = tabularLore_small.surrogate
num_classes = len(class_names)  # o el número total de clases del problema

for i, tree in enumerate(ensemble.trees):
    supertree = SuperTree()
    root = supertree.rec_buildTree(tree, list(range(tree.n_features_in_)), num_classes)

    dot = visualize_individual_binary_tree(root, feature_names=feature_names, class_names=class_names)
    display(dot)  # 👈 Esto lo muestra directamente
# Out:
# 2025-05-20 13:38:34,451 graphviz.backend.execute DEBUG    run [WindowsPath('dot'), '-Kdot', '-Tsvg']

# %% [markdown]
# #### Supertree sin podar

# %%
# Guardar también el árbol sin podar
ensemble = tabularLore_small.surrogate  # ya está entrenado internamente
unpruned_tree = SuperTree()
roots = [unpruned_tree.rec_buildTree(tree, list(range(tree.n_features_in_)), num_classes) for tree in ensemble.trees]
unpruned_tree.mergeDecisionTrees(roots, num_classes=ensemble.trees[0].n_classes_,feature_names=feature_names)

# Guardar dentro de explanation_small
explanation_small["unpruned_tree"] = unpruned_tree

visualize_supertree(
    explanation_small["unpruned_tree"].root,
    feature_names=feature_names,
    class_names=class_names
).render('supertree_unpruned', format='png', cleanup=True)

Image(filename='supertree_unpruned.png')
# Out:
# 2025-05-20 13:38:47,479 graphviz.saving DEBUG    write lines to 'supertree_unpruned'
# 2025-05-20 13:38:47,480 graphviz.backend.execute DEBUG    run [WindowsPath('dot'), '-Kdot', '-Tpng', '-O', 'supertree_unpruned']
# 2025-05-20 13:38:47,630 graphviz.rendering DEBUG    delete 'supertree_unpruned'

# %% [markdown]
# #### SuperTree con la poda

# %%
# Generar el supertree y visualizarlo
merged = explanation_small["merged_tree"]
visualize_supertree(merged.root, feature_names=feature_names, class_names=class_names).render('supertree', format='png', cleanup=True)

# Mostrar la imagen renderizada
Image(filename='supertree.png')
# Out:
# 2025-05-20 13:38:51,546 graphviz.saving DEBUG    write lines to 'supertree'
# 2025-05-20 13:38:51,548 graphviz.backend.execute DEBUG    run [WindowsPath('dot'), '-Kdot', '-Tpng', '-O', 'supertree']
# 2025-05-20 13:38:51,644 graphviz.rendering DEBUG    delete 'supertree'

# %%
x = dataset_small.df.iloc[num_row][:-1]
print(x)

y = dataset_small.df.iloc[num_row][-1]
print(y)
# Out:
# sepal length (cm)    5.4
# sepal width (cm)     3.9
# petal length (cm)    1.7
# petal width (cm)     0.4
# Name: 5, dtype: object
# setosa

# %% [markdown]
# Comprobamos que se cumplen las reglas para la instancia que queremos explicar.

# %%
def check_rule_validity_v2(X, y, explanation, dataset_name="Train", decimals=1):
    """
    Comprueba cuántas instancias cumplen la regla generada por LORE,
    mostrando la regla principal antes de la evaluación.
    """
    rule = explanation['rule']
    conditions = rule['premises']
    target_class = rule['consequence']['val']

    print(f"\n{'='*70}")
    print(f"✅ Condiciones necesarias para que la flor sea clasificada como '{target_class}':")
    for cond in conditions:
        attr, op, val = cond['attr'], cond['op'], round(cond['val'], decimals)
        print(f"  - {attr} {op} {val}")

    print(f"\n{'='*70}")
    print(f"✅ Comprobando regla para la clase '{target_class}' en el {dataset_name}...")
    print(f"{'='*70}")

    valid_instances = []
    incorrect_classifications = 0  

    indices_clase_objetivo = [i for i in range(len(y)) if y[i] == target_class]

    if not indices_clase_objetivo:
        print(f"🚫 No hay instancias de la clase '{target_class}' en {dataset_name}.")
        return  # No hay instancias de esta clase, terminamos la función.

    for i in indices_clase_objetivo:
        cumple_todas = True
        print(f"\n🔎 Instancia {i}: {X[i]} - Clase real: {y[i]}")

        for cond in conditions:
            attr, op, val = cond['attr'], cond['op'], round(cond['val'], decimals)
            col_index = list(dataset_small.df.columns).index(attr)
            instancia_val = round(X[i, col_index], decimals)

            if op == ">":
                cumple = instancia_val > val
            elif op == "<":
                cumple = instancia_val < val
            elif op == ">=":
                cumple = instancia_val >= val
            elif op == "<=":
                cumple = instancia_val <= val
            elif op == "!=":
                cumple = instancia_val != val
            elif op == "=":
                cumple = instancia_val == val

            print(f"   - {attr} {op} {val} → Valor en la instancia: {instancia_val} {'✅' if cumple else '❌'}")
            cumple_todas &= cumple

        if cumple_todas:
            valid_instances.append(i)
        else:
            incorrect_classifications += 1

    # Resultados finales
    print(f"\n🔍 {len(valid_instances)} de {len(indices_clase_objetivo)} instancias de '{target_class}' cumplen la regla completamente.")
    print(f"✅ {len(valid_instances)} realmente son '{target_class}'.")
    print(f"❌ {incorrect_classifications} fueron clasificadas incorrectamente.")
    print(f"{'='*70}")

# 📌 Validar la regla en entrenamiento y test
check_rule_validity_v2(X_train, y_train, explanation_small, dataset_name="Train")
check_rule_validity_v2(X_test, y_test, explanation_small, dataset_name="Test")
# Out:
# ======================================================================
# ✅ Condiciones necesarias para que la flor sea clasificada como 'setosa':
#   - petal length (cm) <= 2.4
#
# ======================================================================
# ✅ Comprobando regla para la clase 'setosa' en el Train...
# ======================================================================
#
# 🔎 Instancia 2: [5.1 3.8 1.5 0.3] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.5 ✅
#
# 🔎 Instancia 6: [4.9 3.1 1.5 0.1] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.5 ✅
#
# 🔎 Instancia 7: [5.1 3.8 1.6 0.2] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.6 ✅
#
# 🔎 Instancia 8: [4.4 2.9 1.4 0.2] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.4 ✅
#
# 🔎 Instancia 11: [4.9 3.  1.4 0.2] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.4 ✅
#
# 🔎 Instancia 12: [5.  3.  1.6 0.2] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.6 ✅
#
# 🔎 Instancia 16: [5.  3.4 1.6 0.4] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.6 ✅
#
# 🔎 Instancia 17: [4.7 3.2 1.6 0.2] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.6 ✅
#
# 🔎 Instancia 20: [5.4 3.4 1.5 0.4] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.5 ✅
#
# 🔎 Instancia 25: [4.6 3.4 1.4 0.3] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.4 ✅
#
# 🔎 Instancia 26: [5.1 3.7 1.5 0.4] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.5 ✅
#
# 🔎 Instancia 27: [5.4 3.9 1.3 0.4] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.3 ✅
#
# 🔎 Instancia 30: [5.7 4.4 1.5 0.4] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.5 ✅
#
# 🔎 Instancia 31: [5.1 3.5 1.4 0.3] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.4 ✅
#
# 🔎 Instancia 34: [4.8 3.  1.4 0.1] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.4 ✅
#
# 🔎 Instancia 35: [4.8 3.  1.4 0.3] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.4 ✅
#
# 🔎 Instancia 39: [5.1 3.5 1.4 0.2] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.4 ✅
#
# 🔎 Instancia 41: [4.6 3.2 1.4 0.2] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.4 ✅
#
# 🔎 Instancia 43: [5.5 3.5 1.3 0.2] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.3 ✅
#
# 🔎 Instancia 46: [4.8 3.4 1.9 0.2] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.9 ✅
#
# 🔎 Instancia 51: [4.5 2.3 1.3 0.3] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.3 ✅
#
# 🔎 Instancia 56: [5.1 3.4 1.5 0.2] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.5 ✅
#
# 🔎 Instancia 58: [5.  3.6 1.4 0.2] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.4 ✅
#
# 🔎 Instancia 67: [4.9 3.1 1.5 0.2] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.5 ✅
#
# 🔎 Instancia 72: [5.2 4.1 1.5 0.1] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.5 ✅
#
# 🔎 Instancia 76: [4.8 3.1 1.6 0.2] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.6 ✅
#
# 🔎 Instancia 79: [5.1 3.8 1.9 0.4] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.9 ✅
#
# 🔎 Instancia 80: [4.3 3.  1.1 0.1] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.1 ✅
#
# 🔎 Instancia 84: [5.4 3.9 1.7 0.4] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.7 ✅
#
# 🔎 Instancia 89: [5.3 3.7 1.5 0.2] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.5 ✅
#
# 🔎 Instancia 95: [5.2 3.5 1.5 0.2] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.5 ✅
#
# 🔎 Instancia 99: [4.8 3.4 1.6 0.2] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.6 ✅
#
# 🔎 Instancia 100: [4.9 3.6 1.4 0.1] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.4 ✅
#
# 🔎 Instancia 102: [5.5 4.2 1.4 0.2] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.4 ✅
#
# 🔎 Instancia 104: [4.6 3.1 1.5 0.2] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.5 ✅
#
# 🔍 35 de 35 instancias de 'setosa' cumplen la regla completamente.
# ✅ 35 realmente son 'setosa'.
# ❌ 0 fueron clasificadas incorrectamente.
# ======================================================================
#
# ======================================================================
# ✅ Condiciones necesarias para que la flor sea clasificada como 'setosa':
#   - petal length (cm) <= 2.4
#
# ======================================================================
# ✅ Comprobando regla para la clase 'setosa' en el Test...
# ======================================================================
#
# 🔎 Instancia 8: [5.4 3.4 1.7 0.2] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.7 ✅
#
# 🔎 Instancia 10: [5.8 4.  1.2 0.2] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.2 ✅
#
# 🔎 Instancia 11: [4.4 3.  1.3 0.2] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.3 ✅
#
# 🔎 Instancia 14: [5.2 3.4 1.4 0.2] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.4 ✅
#
# 🔎 Instancia 17: [5.4 3.7 1.5 0.2] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.5 ✅
#
# 🔎 Instancia 18: [5.1 3.3 1.7 0.5] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.7 ✅
#
# 🔎 Instancia 19: [5.7 3.8 1.7 0.3] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.7 ✅
#
# 🔎 Instancia 21: [5.  3.4 1.5 0.2] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.5 ✅
#
# 🔎 Instancia 29: [5.  3.2 1.2 0.2] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.2 ✅
#
# 🔎 Instancia 33: [5.  3.3 1.4 0.2] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.4 ✅
#
# 🔎 Instancia 35: [5.  3.5 1.3 0.3] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.3 ✅
#
# 🔎 Instancia 36: [4.4 3.2 1.3 0.2] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.3 ✅
#
# 🔎 Instancia 37: [4.7 3.2 1.3 0.2] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.3 ✅
#
# 🔎 Instancia 38: [5.  3.5 1.6 0.6] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.6 ✅
#
# 🔎 Instancia 41: [4.6 3.6 1.  0.2] - Clase real: setosa
#    - petal length (cm) <= 2.4 → Valor en la instancia: 1.0 ✅
#
# 🔍 15 de 15 instancias de 'setosa' cumplen la regla completamente.
# ✅ 15 realmente son 'setosa'.
# ❌ 0 fueron clasificadas incorrectamente.
# ======================================================================

# %%
def check_counterfactuals(X, y, explanation, dataset_name="Train", decimals=1):
    """
    Evalúa los contrafactuales en un dataset (Train/Test) para verificar cuántas instancias reales cumplen sus condiciones.
    """
    counterfactuals = explanation['counterfactuals']

    print(f"\n{'='*70}")
    print(f"🔄 Comprobando CONTRAFACTUALES en el dataset {dataset_name}...")
    # print(f"{'='*70}")

    for idx, cf in enumerate(counterfactuals, start=1):
        conditions = cf['premises']
        target_class = cf['consequence']['val']

        print(f"\n🛑 CASO {idx}: Si se cumplen estas condiciones, la flor sería clasificada como '{target_class}'")
        for cond in conditions:
            attr, op, val = cond['attr'], cond['op'], round(cond['val'], decimals)
            print(f"  - {attr} {op} {val}")

        print("\n🔎 Evaluando instancias en el dataset...")
        valid_instances = []
        incorrect_classifications = 0

        # Filtrar solo las instancias que ya son de la clase objetivo del contrafactual
        indices_clase_objetivo = [i for i in range(len(y)) if y[i] == target_class]

        if not indices_clase_objetivo:
            print(f"🚫 No hay instancias de la clase '{target_class}' en {dataset_name}.")
            continue

        for i in indices_clase_objetivo:
            cumple_todas = True
            print(f"\n Instancia {i}: {X[i]} - Clase real: {y[i]}")

            for cond in conditions:
                attr, op, val = cond['attr'], cond['op'], round(cond['val'], decimals)
                col_index = list(dataset_small.df.columns).index(attr)
                instancia_val = round(X[i, col_index], decimals)

                if op == ">":
                    cumple = instancia_val > val
                elif op == "<":
                    cumple = instancia_val < val
                elif op == ">=":
                    cumple = instancia_val >= val
                elif op == "<=":
                    cumple = instancia_val <= val
                elif op == "!=":
                    cumple = instancia_val != val
                elif op == "=":
                    cumple = instancia_val == val

                print(f"   - {attr} {op} {val} → Valor en la instancia: {instancia_val} {'✅' if cumple else '❌'}")
                cumple_todas &= cumple

            if cumple_todas:
                valid_instances.append(i)
            else:
                incorrect_classifications += 1

        # Resultados finales del contrafactual
        print(f"\n✅ {len(valid_instances)} de {len(indices_clase_objetivo)} instancias de '{target_class}' cumplen el contrafactual completamente.")
        # print(f" {len(valid_instances)} realmente son '{target_class}'.")
        print(f"❌ {incorrect_classifications} fueron clasificadas incorrectamente.")
        print(f"{'='*70}")

# 📌 Evaluar contrafactuales en Train y Test
check_counterfactuals(X_train, y_train, explanation_small, dataset_name="Train")
check_counterfactuals(X_test, y_test, explanation_small, dataset_name="Test")
# Out:
# ======================================================================
# 🔄 Comprobando CONTRAFACTUALES en el dataset Train...
#
# 🛑 CASO 1: Si se cumplen estas condiciones, la flor sería clasificada como 'virginica'
#   - petal length (cm) > 5.0
#
# 🔎 Evaluando instancias en el dataset...
#
#  Instancia 3: [6.8 3.2 5.9 2.3] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 5.9 ✅
#
#  Instancia 5: [6.7 3.  5.2 2.3] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 5.2 ✅
#
#  Instancia 9: [7.1 3.  5.9 2.1] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 5.9 ✅
#
#  Instancia 10: [6.5 3.2 5.1 2. ] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 5.1 ✅
#
#  Instancia 15: [7.2 3.2 6.  1.8] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 6.0 ✅
#
#  Instancia 18: [6.7 3.3 5.7 2.5] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 5.7 ✅
#
#  Instancia 21: [6.3 2.7 4.9 1.8] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 4.9 ❌
#
#  Instancia 22: [7.6 3.  6.6 2.1] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 6.6 ✅
#
#  Instancia 23: [7.7 2.8 6.7 2. ] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 6.7 ✅
#
#  Instancia 37: [6.3 2.5 5.  1.9] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 5.0 ❌
#
#  Instancia 38: [7.9 3.8 6.4 2. ] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 6.4 ✅
#
#  Instancia 40: [6.4 2.8 5.6 2.1] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 5.6 ✅
#
#  Instancia 42: [6.  2.2 5.  1.5] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 5.0 ❌
#
#  Instancia 44: [6.3 3.3 6.  2.5] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 6.0 ✅
#
#  Instancia 47: [7.7 3.  6.1 2.3] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 6.1 ✅
#
#  Instancia 49: [5.7 2.5 5.  2. ] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 5.0 ❌
#
#  Instancia 53: [6.4 3.1 5.5 1.8] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 5.5 ✅
#
#  Instancia 55: [6.3 2.9 5.6 1.8] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 5.6 ✅
#
#  Instancia 62: [7.2 3.6 6.1 2.5] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 6.1 ✅
#
#  Instancia 65: [6.3 3.4 5.6 2.4] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 5.6 ✅
#
#  Instancia 66: [5.6 2.8 4.9 2. ] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 4.9 ❌
#
#  Instancia 68: [6.9 3.2 5.7 2.3] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 5.7 ✅
#
#  Instancia 71: [7.7 2.6 6.9 2.3] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 6.9 ✅
#
#  Instancia 73: [6.4 3.2 5.3 2.3] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 5.3 ✅
#
#  Instancia 74: [5.9 3.  5.1 1.8] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 5.1 ✅
#
#  Instancia 77: [7.7 3.8 6.7 2.2] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 6.7 ✅
#
#  Instancia 78: [6.8 3.  5.5 2.1] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 5.5 ✅
#
#  Instancia 81: [6.2 2.8 4.8 1.8] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 4.8 ❌
#
#  Instancia 82: [7.2 3.  5.8 1.6] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 5.8 ✅
#
#  Instancia 83: [5.8 2.8 5.1 2.4] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 5.1 ✅
#
#  Instancia 85: [5.8 2.7 5.1 1.9] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 5.1 ✅
#
#  Instancia 87: [6.7 3.3 5.7 2.1] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 5.7 ✅
#
#  Instancia 88: [7.4 2.8 6.1 1.9] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 6.1 ✅
#
#  Instancia 96: [6.9 3.1 5.4 2.1] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 5.4 ✅
#
#  Instancia 98: [5.8 2.7 5.1 1.9] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 5.1 ✅
#
# ✅ 29 de 35 instancias de 'virginica' cumplen el contrafactual completamente.
# ❌ 6 fueron clasificadas incorrectamente.
# ======================================================================
#
# 🛑 CASO 2: Si se cumplen estas condiciones, la flor sería clasificada como 'versicolor'
#   - petal length (cm) <= 5.0
#   - petal length (cm) > 2.4
#   - petal width (cm) <= 1.9
#
# 🔎 Evaluando instancias en el dataset...
#
#  Instancia 0: [5.1 2.5 3.  1.1] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 3.0 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 3.0 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.1 ✅
#
#  Instancia 1: [6.2 2.2 4.5 1.5] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.5 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.5 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.5 ✅
#
#  Instancia 4: [5.7 2.8 4.1 1.3] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.1 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.1 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.3 ✅
#
#  Instancia 13: [6.  2.9 4.5 1.5] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.5 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.5 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.5 ✅
#
#  Instancia 14: [5.5 2.4 3.8 1.1] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 3.8 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 3.8 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.1 ✅
#
#  Instancia 19: [5.9 3.2 4.8 1.8] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.8 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.8 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.8 ✅
#
#  Instancia 24: [5.7 3.  4.2 1.2] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.2 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.2 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.2 ✅
#
#  Instancia 28: [6.9 3.1 4.9 1.5] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.9 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.9 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.5 ✅
#
#  Instancia 29: [5.5 2.5 4.  1.3] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.0 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.0 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.3 ✅
#
#  Instancia 32: [5.8 2.7 4.1 1. ] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.1 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.1 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.0 ✅
#
#  Instancia 33: [5.6 2.9 3.6 1.3] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 3.6 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 3.6 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.3 ✅
#
#  Instancia 36: [6.7 3.1 4.4 1.4] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.4 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.4 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.4 ✅
#
#  Instancia 45: [6.  2.2 4.  1. ] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.0 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.0 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.0 ✅
#
#  Instancia 48: [6.1 2.8 4.  1.3] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.0 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.0 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.3 ✅
#
#  Instancia 50: [5.8 2.7 3.9 1.2] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 3.9 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 3.9 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.2 ✅
#
#  Instancia 52: [5.5 2.4 3.7 1. ] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 3.7 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 3.7 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.0 ✅
#
#  Instancia 54: [6.1 3.  4.6 1.4] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.6 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.6 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.4 ✅
#
#  Instancia 57: [5.7 2.9 4.2 1.3] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.2 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.2 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.3 ✅
#
#  Instancia 59: [6.7 3.1 4.7 1.5] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.7 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.7 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.5 ✅
#
#  Instancia 60: [6.8 2.8 4.8 1.4] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.8 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.8 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.4 ✅
#
#  Instancia 61: [5.2 2.7 3.9 1.4] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 3.9 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 3.9 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.4 ✅
#
#  Instancia 63: [6.  2.7 5.1 1.6] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 5.1 ❌
#    - petal length (cm) > 2.4 → Valor en la instancia: 5.1 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.6 ✅
#
#  Instancia 64: [6.4 2.9 4.3 1.3] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.3 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.3 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.3 ✅
#
#  Instancia 69: [6.5 2.8 4.6 1.5] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.6 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.6 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.5 ✅
#
#  Instancia 70: [5.6 3.  4.1 1.3] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.1 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.1 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.3 ✅
#
#  Instancia 75: [6.3 2.3 4.4 1.3] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.4 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.4 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.3 ✅
#
#  Instancia 86: [5.  2.  3.5 1. ] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 3.5 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 3.5 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.0 ✅
#
#  Instancia 90: [6.1 2.8 4.7 1.2] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.7 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.7 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.2 ✅
#
#  Instancia 91: [5.5 2.6 4.4 1.2] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.4 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.4 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.2 ✅
#
#  Instancia 92: [7.  3.2 4.7 1.4] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.7 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.7 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.4 ✅
#
#  Instancia 93: [6.3 2.5 4.9 1.5] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.9 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.9 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.5 ✅
#
#  Instancia 94: [5.9 3.  4.2 1.5] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.2 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.2 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.5 ✅
#
#  Instancia 97: [5.8 2.6 4.  1.2] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.0 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.0 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.2 ✅
#
#  Instancia 101: [5.7 2.6 3.5 1. ] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 3.5 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 3.5 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.0 ✅
#
#  Instancia 103: [5.6 2.7 4.2 1.3] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.2 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.2 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.3 ✅
#
# ✅ 34 de 35 instancias de 'versicolor' cumplen el contrafactual completamente.
# ❌ 1 fueron clasificadas incorrectamente.
# ======================================================================
#
# ======================================================================
# 🔄 Comprobando CONTRAFACTUALES en el dataset Test...
#
# 🛑 CASO 1: Si se cumplen estas condiciones, la flor sería clasificada como 'virginica'
#   - petal length (cm) > 5.0
#
# 🔎 Evaluando instancias en el dataset...
#
#  Instancia 0: [7.3 2.9 6.3 1.8] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 6.3 ✅
#
#  Instancia 2: [6.3 2.8 5.1 1.5] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 5.1 ✅
#
#  Instancia 4: [6.1 3.  4.9 1.8] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 4.9 ❌
#
#  Instancia 5: [6.7 3.1 5.6 2.4] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 5.6 ✅
#
#  Instancia 9: [6.9 3.1 5.1 2.3] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 5.1 ✅
#
#  Instancia 12: [6.7 2.5 5.8 1.8] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 5.8 ✅
#
#  Instancia 13: [6.5 3.  5.5 1.8] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 5.5 ✅
#
#  Instancia 15: [6.2 3.4 5.4 2.3] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 5.4 ✅
#
#  Instancia 23: [6.5 3.  5.8 2.2] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 5.8 ✅
#
#  Instancia 24: [6.  3.  4.8 1.8] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 4.8 ❌
#
#  Instancia 30: [6.1 2.6 5.6 1.4] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 5.6 ✅
#
#  Instancia 31: [6.4 2.8 5.6 2.2] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 5.6 ✅
#
#  Instancia 34: [6.4 2.7 5.3 1.9] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 5.3 ✅
#
#  Instancia 42: [4.9 2.5 4.5 1.7] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 4.5 ❌
#
#  Instancia 43: [6.5 3.  5.2 2. ] - Clase real: virginica
#    - petal length (cm) > 5.0 → Valor en la instancia: 5.2 ✅
#
# ✅ 12 de 15 instancias de 'virginica' cumplen el contrafactual completamente.
# ❌ 3 fueron clasificadas incorrectamente.
# ======================================================================
#
# 🛑 CASO 2: Si se cumplen estas condiciones, la flor sería clasificada como 'versicolor'
#   - petal length (cm) <= 5.0
#   - petal length (cm) > 2.4
#   - petal width (cm) <= 1.9
#
# 🔎 Evaluando instancias en el dataset...
#
#  Instancia 1: [6.1 2.9 4.7 1.4] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.7 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.7 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.4 ✅
#
#  Instancia 3: [6.3 3.3 4.7 1.6] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.7 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.7 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.6 ✅
#
#  Instancia 6: [5.5 2.3 4.  1.3] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.0 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.0 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.3 ✅
#
#  Instancia 7: [5.6 2.5 3.9 1.1] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 3.9 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 3.9 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.1 ✅
#
#  Instancia 16: [4.9 2.4 3.3 1. ] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 3.3 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 3.3 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.0 ✅
#
#  Instancia 20: [6.2 2.9 4.3 1.3] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.3 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.3 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.3 ✅
#
#  Instancia 22: [6.6 3.  4.4 1.4] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.4 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.4 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.4 ✅
#
#  Instancia 25: [6.4 3.2 4.5 1.5] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.5 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.5 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.5 ✅
#
#  Instancia 26: [5.4 3.  4.5 1.5] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.5 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.5 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.5 ✅
#
#  Instancia 27: [5.  2.3 3.3 1. ] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 3.3 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 3.3 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.0 ✅
#
#  Instancia 28: [5.6 3.  4.5 1.5] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.5 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.5 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.5 ✅
#
#  Instancia 32: [6.  3.4 4.5 1.6] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.5 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.5 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.6 ✅
#
#  Instancia 39: [6.7 3.  5.  1.7] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 5.0 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 5.0 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.7 ✅
#
#  Instancia 40: [5.7 2.8 4.5 1.3] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.5 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.5 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.3 ✅
#
#  Instancia 44: [6.6 2.9 4.6 1.3] - Clase real: versicolor
#    - petal length (cm) <= 5.0 → Valor en la instancia: 4.6 ✅
#    - petal length (cm) > 2.4 → Valor en la instancia: 4.6 ✅
#    - petal width (cm) <= 1.9 → Valor en la instancia: 1.3 ✅
#
# ✅ 15 de 15 instancias de 'versicolor' cumplen el contrafactual completamente.
# ❌ 0 fueron clasificadas incorrectamente.
# ======================================================================

# %% [markdown]
# Evaluamos la estabilidad

# %% [markdown]
# Comprobamos si es accionable
#
#  No se puede porque según tengo entendido, la accionabilidad tiene sentido si esos cambios representan una acción realista en la vida real, en Iris modificar el sepal length (por ejemplo) no es una acción que la flor pueda "decidir".
